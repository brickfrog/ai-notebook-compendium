# %%
import langfun as lf
import pyglove as pg

# %%
class Answer(pg.Object):
  result: int

r = lf.query(prompt='The result of one plus two is three', schema=Answer, lm=lf.llms.Gpt4o())
print(r)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 class Answer(pg.Object):
#       2   result: int
# ----> 4 r = lf.query(prompt='The result of one plus two is three', schema=Answer, lm=lf.llms.Gpt4o())
#       5 print(r)
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/structured/prompting.py:226, in query(prompt, schema, default, lm, examples, cache_seed, response_postprocess, autofix, autofix_lm, protocol, returns_message, skip_lm, **kwargs)
#     223 else:
#     224   prompt = schema_lib.mark_missing(prompt)
# --> 226 output = _query_structure_cls(protocol)(
#     227     input=prompt,
#     228     schema=schema,
#     229     default=default,
#     230     examples=examples,
#     231     response_postprocess=response_postprocess,
#     232     autofix=autofix if protocol == 'python' else 0,
#     233     **kwargs,
#     234 )(
#     235     lm=lm,
#     236     autofix_lm=autofix_lm or lm,
#     237     cache_seed=cache_seed,
#     238     skip_lm=skip_lm,
#     239 )
#     240 return output if returns_message else output.result
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/langfunc.py:234, in LangFunc.__call__(self, lm, lm_input, cache_seed, skip_lm, **variables)
#     207 def __call__(
#     208     self,
#     209     *,
#    (...)
#     214     **variables,
#     215 ) -> message_lib.Message:
#     216   """Calls language model with `lm_input` or rendered text.
#     217
#     218   Args:
#    (...)
#     232     An output message from LM.
#     233   """
# --> 234   return self._call_once(
#     235       lm=lm,
#     236       lm_input=lm_input,
#     237       cache_seed=cache_seed,
#     238       skip_lm=skip_lm,
#     239       **variables,
#     240   )
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/langfunc.py:270, in LangFunc._call_once(self, lm, lm_input, cache_seed, skip_lm, **variables)
#     267 self._cached_lm_input = lm_input
#     269 # Send rendered text to LM.
# --> 270 lm_output = self.lm(lm_input, cache_seed=cache_seed)
#     272 # Attach cache seed.
#     273 lm_input.metadata.cache_seed = cache_seed
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/language_model.py:605, in LanguageModel.__call__(self, prompt, cache_seed, **kwargs)
#     603 self._call_counter += 1
#     604 request_start = time.time()
# --> 605 result = self.sample(
#     606     [prompt], sampling_options=sampling_options, cache_seed=cache_seed
#     607 )[0]
#     608 elapse = time.time() - request_start
#     609 response = result.samples[0].response
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/language_model.py:468, in LanguageModel.sample(self, prompts, cache_seed, **kwargs)
#     466 with component.context(override_attrs=True, **kwargs):
#     467   if self.cache is None:
# --> 468     results = self._sample(prompts)
#     469   else:
#     470     results = self._sample_with_cache_lookup(prompts, cache_seed)
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/llms/openai.py:467, in OpenAI._sample(self, prompts)
#     465 assert self._api_initialized
#     466 if self.is_chat_model:
# --> 467   return self._chat_complete_batch(prompts)
#     468 else:
#     469   return self._complete_batch(prompts)
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/llms/openai.py:614, in OpenAI._chat_complete_batch(self, prompts)
#     593     samples.append(
#     594         lf.LMSample(
#     595             choice.message.content,
#    (...)
#     598         )
#     599     )
#     601   return lf.LMSamplingResult(
#     602       samples=samples,
#     603       usage=lf.LMSamplingUsage(
#    (...)
#     611       ),
#     612   )
# --> 614 return self._parallel_execute_with_currency_control(
#     615     _open_ai_chat_completion,
#     616     prompts,
#     617     retry_on_errors=(
#     618         ServiceUnavailableError,
#     619         RateLimitError,
#     620         APITimeoutError
#     621     ),
#     622 )
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/language_model.py:581, in LanguageModel._parallel_execute_with_currency_control(self, action, inputs, retry_on_errors)
#     570 def _parallel_execute_with_currency_control(
#     571     self,
#     572     action: Callable[..., Any],
#    (...)
#     578     ] = RetryableLMError,
#     579 ) -> Any:
#     580   """Helper method for subclasses for implementing _sample."""
# --> 581   return concurrent.concurrent_execute(
#     582       action,
#     583       inputs,
#     584       executor=self.resource_id if self.max_concurrency else None,
#     585       max_workers=self.max_concurrency or len(inputs),
#     586       retry_on_errors=retry_on_errors,
#     587       max_attempts=self.max_attempts,
#     588       retry_interval=self.retry_interval,
#     589       exponential_backoff=self.exponential_backoff,
#     590   )
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/concurrent.py:240, in concurrent_execute(func, parallel_inputs, executor, max_workers, retry_on_errors, max_attempts, retry_interval, exponential_backoff)
#     237 executor = _executor_pool.executor_from(executor, max_workers=max_workers)
#     239 try:
# --> 240   return list(executor.map(with_context_access(func), parallel_inputs))
#     241 finally:
#     242   if shutdown_after_finish:
#     243     # Do not wait threads to finish if they are timed out.
#
# File ~/.conda/envs/llm/lib/python3.11/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/.conda/envs/llm/lib/python3.11/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/.conda/envs/llm/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.conda/envs/llm/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.conda/envs/llm/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/concurrent.py:49, in with_context_access.<locals>._func(*args, **kwargs)
#      47 def _func(*args, **kwargs) -> Any:
#      48   with component.context(**current_context):
# ---> 49     return func(*args, **kwargs)
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/concurrent.py:162, in with_retry.<locals>._func(*args, **kwargs)
#     160 while True:
#     161   with pg.catch_errors(retry_on_errors) as error_context:
# --> 162     return func(*args, **kwargs)
#     164   # Branch when errors are met for retry.
#     165   errors.append(error_context.error)
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/langfun/core/llms/openai.py:578, in OpenAI._chat_complete_batch.<locals>._open_ai_chat_completion(prompt)
#     575 messages.append(dict(role='user', content=_content_from_message(prompt)))
#     577 assert openai is not None
# --> 578 response = openai.ChatCompletion.create(messages=messages, **request_args)
#     580 samples = []
#     581 for choice in response.choices:
#
# File ~/Documents/Code/ai-notebook-compendium/notebooks/langfun-notebooks/.venv/lib/python3.11/site-packages/openai/lib/_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742

# %%
# !pip list
# Out:
# Package            Version
# ------------------ -----------------------------
# annotated-types    0.7.0
# ansible            10.5.0
# ansible-core       2.17.5
# apsw               3.46.1.0
# arandr             0.1.11
# argcomplete        3.4.0
# asciidoc           10.2.1
# async-timeout      4.0.3
# attrs              23.2.1.dev0
# autocommand        2.2.2
# autotiling         1.9.3
# bcrypt             4.1.3
# beautifulsoup4     4.12.3
# Brotli             1.1.0
# brotlicffi         1.1.0.0
# btrfsutil          6.10
# certifi            2024.8.30
# cffi               1.17.1
# chardet            5.2.0
# charset-normalizer 3.4.0
# click              8.1.7
# colorama           0.4.6
# coverage           7.6.2
# cryptography       42.0.8
# css-parser         1.0.10
# cssselect          1.2.0
# dbus-python        1.3.2
# decorator          5.1.1
# defusedxml         0.7.1
# distlib            0.3.8
# distro             1.9.0
# dnspython          2.6.1
# docutils           0.21.2
# evdev              1.7.1
# fastjsonschema     2.20.0
# faust-cchardet     2.1.19
# feedparser         6.0.11
# filelock           3.13.3
# future             1.0.0
# glad2              2.0.8
# Glances            4.1.2
# html2text          2024.2.26
# html5-parser       0.4.12
# html5lib           1.1
# i3ipc              2.2.1
# idna               3.8
# ifaddr             0.2.0
# inflate64          1.0.0
# inflect            7.4.0
# isodate            0.6.1
# jaraco.context     5.3.0
# jaraco.functools   4.0.2
# jaraco.text        4.0.0
# jeepney            0.8.0
# Jinja2             3.1.4
# lensfun            0.3.4
# libtorrent         2.0.10
# lit                18.1.8.dev0
# lxml               5.3.0
# lxml_html_clean    0.2.0
# Mako               1.3.5.dev0
# Markdown           3.7
# MarkupSafe         2.1.5
# mechanize          0.4.10
# meson              1.5.2
# moddb              0.11.0
# more-itertools     10.3.0
# msgpack            1.0.5
# multivolumefile    0.2.3
# netifaces          0.11.0
# netsnmp-python     1.0a1
# nftables           0.1
# nose               1.3.7
# ordered-set        4.1.0
# orjson             3.10.7
# packaging          24.1
# paramiko           3.4.0
# pdftotext          2.2.2
# perf               0.1
# pillow             10.4.0
# pip                24.2
# pipenv             2024.1.0
# pipx               1.6.0
# platformdirs       4.3.6
# protontricks       1.12.0
# psutil             6.0.0
# py7zr              0.22.0
# pybcj              1.0.2
# pycairo            1.27.0
# pychm              0.8.6
# pycparser          2.22
# pycryptodome       3.21.0
# pycryptodomex      3.20.0
# pydantic           2.9.2
# pydantic_core      2.23.4
# Pygments           2.18.0
# PyGObject          3.50.0
# pyinotify          0.9.6
# PyNaCl             1.5.0
# pyparsing          3.1.2
# pyppmd             1.1.0
# PyQt5              5.15.11
# PyQt5_sip          12.15.0
# PyQt6              6.8.0.dev2410141303
# PyQt6_sip          13.8.0
# PyQt6-WebEngine    6.7.0
# pyte               0.8.2
# python-dateutil    2.9.0
# python-xlib        0.33
# pyxdg              0.28
# PyYAML             6.0.2
# pyzstd             0.16.2
# rdflib             7.0.0
# Reflector          2023.6.28.0.36.1
# regex              2024.9.11
# requests           2.32.3
# resolvelib         1.0.1
# setuptools         69.5.1
# sgmllib3k          1.0.0
# shtab              1.7.2.dev0+g61ec99d.d20241005
# six                1.16.0
# soupsieve          2.6
# TBB                0.2
# termcolor          2.4.0
# texttable          1.7.0
# thefuck            3.32
# tldr               3.3.0
# tomli              2.0.1
# tqdm               4.66.5
# trackma            0.8.6
# trove-classifiers  2024.9.17
# typeguard          4.3.0
# typing_extensions  4.12.2
# ufw                0.36.2
# unrardll           0.1.7
# urllib3            1.26.20
# userpath           1.9.2
# validate-pyproject 0.20.2
# vdf                3.5
# virtualenv         20.26.2
# virtualenv-clone   0.5.7
# wcwidth            0.2.13
# webencodings       0.5.1
# wheel              0.44.0
# xxhash             3.4.1
# yt-dlp             2024.10.7
# zeroconf           0.132.2
# zstandard          0.22.0
